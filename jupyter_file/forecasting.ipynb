# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
path_dataset = "../dataset/PM2.5/"
# load all files
all_files = glob.glob(path_dataset + "/*.xlsx")

# %%
all_files = sorted(all_files)
all_files
# Out:
# ['../dataset/PM2.5/PM2.5(2011).xlsx',
#  '../dataset/PM2.5/PM2.5(2012).xlsx',
#  '../dataset/PM2.5/PM2.5(2013).xlsx',
#  '../dataset/PM2.5/PM2.5(2014).xlsx',
#  '../dataset/PM2.5/PM2.5(2015).xlsx',
#  '../dataset/PM2.5/PM2.5(2016).xlsx',
#  '../dataset/PM2.5/PM2.5(2017).xlsx',
#  '../dataset/PM2.5/PM2.5(2018).xlsx',
#  '../dataset/PM2.5/PM2.5(2019).xlsx',
#  '../dataset/PM2.5/PM2.5(2020).xlsx',
#  '../dataset/PM2.5/PM2.5(2021).xlsx',
#  '../dataset/PM2.5/PM2.5(2022).xlsx',
#  '../dataset/PM2.5/PM2.5(2023).xlsx']

# %%
xls = pd.ExcelFile(all_files[0])
test_df = pd.read_excel(xls, 'PM2.5')

# %%
test_df
# Out:
#                     Date                02T   05T   10T   11T   12T   59T  \
# 0    2019-01-01 00:00:00                NaN  15.0  20.0  22.0   NaN  23.0
# 1    2019-01-02 00:00:00                NaN  21.0  26.0  21.0   NaN  23.0
# 2    2019-01-03 00:00:00                NaN  24.0  26.0  25.0   NaN  24.0
# 3    2019-01-04 00:00:00                NaN  27.0  32.0  29.0   NaN  28.0
# 4    2019-01-05 00:00:00                NaN  33.0  37.0  36.0   NaN  35.0
# ..                   ...                ...   ...   ...   ...   ...   ...
# 362  2019-12-29 00:00:00                 41  40.0  32.0  39.0  37.0  36.0
# 363  2019-12-30 00:00:00                 37  39.0  32.0  37.0  38.0  35.0
# 364  2019-12-31 00:00:00                 41  33.0  32.0  40.0  29.0  36.0
# 365                  NaN                NaN   NaN   NaN   NaN   NaN   NaN
# 366             หมายเหตุ  N/A : ไม่มีข้อมูล   NaN   NaN   NaN   NaN   NaN
#
#       61T   03T   50T  ...   72T   73T   74T   75T   76T   77T   78T   79T  \
# 0     NaN  25.0  22.0  ...  11.0  11.0   NaN   6.0  28.0  18.0   NaN  23.0
# 1     NaN  25.0  25.0  ...  15.0  11.0   NaN   6.0  25.0  20.0   NaN  35.0
# 2     NaN  29.0  28.0  ...  17.0  14.0   NaN   8.0  39.0  23.0   NaN  39.0
# 3    32.0  33.0  31.0  ...  15.0  11.0   NaN   8.0  34.0  24.0   NaN  45.0
# 4    39.0  43.0  34.0  ...  21.0  12.0   NaN   8.0  29.0  27.0   NaN  48.0
# ..    ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 362  41.0  40.0  43.0  ...  26.0  23.0  40.0  20.0  51.0  32.0  11.0  52.0
# 363  38.0  39.0  39.0  ...  29.0  18.0  45.0  20.0  44.0  34.0  11.0  51.0
# 364  41.0  39.0  36.0  ...  25.0  21.0  38.0  17.0  41.0  26.0  10.0  48.0
# 365   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 366   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       80T   81T
# 0    14.0   NaN
# 1    21.0   NaN
# 2    16.0   NaN
# 3    10.0   NaN
# 4    13.0   NaN
# ..    ...   ...
# 362  12.0  37.0
# 363   9.0  54.0
# 364   7.0  44.0
# 365   NaN   NaN
# 366   NaN   NaN
#
# [367 rows x 67 columns]

# %% [markdown]
# # Pre-processing Data

# %%
# Create an empty dataframe for waiting for the concatenation
merged_df = pd.DataFrame(columns=['Date', '36T'])
for file_name in all_files:
    xls = pd.ExcelFile(file_name)
    df = pd.read_excel(xls, 'PM2.5')
    # Drop every row following Date containing NaN
    df = df.dropna(subset=['Date'])
    # Keep only Date and 36T Column
    try:
        df = df[['Date', '36T']]
    except:
        df = df[['Date', '36T ']]
        # rename the column form '36T ' to '36T'
        df = df.rename(columns={'36T ': '36T'})
       
       
    # Convert Date to datetime, if some rows are not in the right format, drop them
    try:
        # Drop last row, then convert to datetime
        df = df[:-1]
        df['Date'] = pd.to_datetime(df['Date'])
    except:
        df['Date'] = pd.to_datetime(df['Date'])
       
    # Concatenate the dataframe
    merged_df = pd.concat([merged_df, df], axis=0)
# reset index
merged_df = merged_df.reset_index(drop=True)
merged_df
# Out:
# /tmp/ipykernel_13823/2510933323.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged_df = pd.concat([merged_df, df], axis=0)
#            Date   36T
# 0    2011-01-01   NaN
# 1    2011-01-02   NaN
# 2    2011-01-03   NaN
# 3    2011-01-04   NaN
# 4    2011-01-05   NaN
# ...         ...   ...
# 4742 2023-12-27  28.7
# 4743 2023-12-28  29.8
# 4744 2023-12-29  23.2
# 4745 2023-12-30  20.2
# 4746 2023-12-31  21.1
#
# [4747 rows x 2 columns]

# %% [markdown]
# # Manipulating Data

# %%
# Plot the data
plt.figure(figsize=(10,5))
plt.plot(merged_df['Date'], merged_df['36T'])
plt.show()

# %%
# Replace the NaN values by the mean of the column
mean_df_copy = merged_df.copy()
mean_df_copy['36T'] = mean_df_copy['36T'].fillna(mean_df_copy['36T'].mean())
plt.figure(figsize=(10,5))
plt.figure(figsize=(10,5))
plt.plot(mean_df_copy['Date'], mean_df_copy['36T'])
plt.show()

# %%
# Replace the NaN values by random values in the range 1 to the mean by each row
random_df_copy = merged_df.copy()
mean_value = random_df_copy['36T'].mean()
random_values = pd.Series(np.random.randint(1, mean_value + 1, size=len(random_df_copy)), index=random_df_copy.index)
random_df_copy['36T'] = random_df_copy['36T'].fillna(random_values)

plt.figure(figsize=(10, 5))
plt.plot(random_df_copy['Date'], random_df_copy['36T'])
plt.show()

# %%
# Replace the NaN values with range 1 to 30
random_df_copy2 = merged_df.copy()
min_ = 1
max_ = 20
random_values = pd.Series(np.random.randint(min_, max_+1, size=len(random_df_copy2)), index=random_df_copy2.index)
random_df_copy2['36T'] = random_df_copy2['36T'].fillna(random_values)

plt.figure(figsize=(10, 5))
plt.plot(random_df_copy2['Date'], random_df_copy2['36T'])
plt.show()

# %% [markdown]
# # Decomposing Data

# %%
from statsmodels.tsa.seasonal import seasonal_decompose


# Decompose the data
decomposed = seasonal_decompose(random_df_copy2['36T'], model='additive', period=365)
# Plot the decomposed components
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(10, 10))
decomposed.observed.plot(ax=ax1)
ax1.set_ylabel('Observed')
decomposed.trend.plot(ax=ax2)
ax2.set_ylabel('Trend')
decomposed.seasonal.plot(ax=ax3)
ax3.set_ylabel('Seasonal')
decomposed.resid.plot(ax=ax4)
ax4.set_ylabel('Residual')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Splitting Data

# %%
# display last rows of the dataframe
random_df_copy2.tail()
# Out:
#            Date   36T
# 4742 2023-12-27  28.7
# 4743 2023-12-28  29.8
# 4744 2023-12-29  23.2
# 4745 2023-12-30  20.2
# 4746 2023-12-31  21.1

# %%
# Split the data into train and test, by 2011-2021 being the train and 2022-2023 the test
train = random_df_copy2[random_df_copy2['Date'].dt.year < 2022]
test = random_df_copy2[random_df_copy2['Date'].dt.year >= 2022]

# %% [markdown]
# # Model Building

# %% [markdown]
# ## ARIMA Model

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# Fit the model

model = ARIMA(train['36T'])
model_fit = model.fit()

# Make predictions
predictions = model_fit.forecast(steps=len(test))
# Calculate the error
error = mean_squared_error(test['36T'], predictions)
error
# Out:
# 767.9238334855756

# %%
# predict on test then plot
plt.figure(figsize=(10,5))
plt.plot(train['Date'], train['36T'], label='Train')
plt.plot(test['Date'], test['36T'], label='Test')
plt.plot(test['Date'], predictions, label='Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ## LSTM Model

# %%
train.shape, test.shape
# Out:
# ((4017, 2), (730, 2))

# %%
# # Set time lag for prediction
# This code work on correct x1, x2, x3, ... x30 to predict x31, x32, x33, ... x60
next_t = 30

# Training data
X_train = []
y_train = []
for i in range(len(train) - next_t):
    # keep the values starting from i to i+next_t in X_train [[x1, x2, x3, ... x30], [x2, x3, x4, ... x31], ...
    # write your code here ...
    X_train.append(train['36T'][i:i+next_t])
    # keep the values starting from i+1 to i+next_t+1 in y_train [[x2, x3, x4, ... x31], [x3, x4, x5, ... x32], ...
    # write your code here ...
    y_train.append(train['36T'][i+1:i+next_t+1])
    
X_train = np.array(X_train)
y_train = np.array(y_train)

# Testing data
X_test = []
y_test = []
for i in range(len(test) - next_t):
    # keep the values starting from i to i+next_t in X_test [[x1, x2, x3, ... x30], [x2, x3, x4, ... x31], ...
    # write your code here ...
    X_test.append(test['36T'][i:i+next_t])
    # keep the values starting from i+1 to i+next_t+1 in y_test [[x2, x3, x4, ... x31], [x3, x4, x5, ... x32], ...
    # write your code here ...
    y_test.append(test['36T'][i+1:i+next_t+1])
    
X_test = np.array(X_test)
y_test = np.array(y_test)

# reshape the data
X_train = X_train.reshape(-1, next_t, 1)
y_train = y_train.reshape(-1, next_t, 1)
X_test = X_test.reshape(-1, next_t, 1)
y_test = y_test.reshape(-1, next_t, 1)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((3987, 30, 1), (3987, 30, 1), (700, 30, 1), (700, 30, 1))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Define the model architecture
model = Sequential()
model.add(LSTM(64, input_shape=(next_t, 1), return_sequences=True))
model.add(Dense(1, activation='relu'))  # Moved activation parameter inside Dense
model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# /opt/conda/envs/ts/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 30, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30, 1)          │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit the model
history = model.fit(X_train, y_train, epochs=200, batch_size=64, verbose=1, shuffle=False, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 1144.6897 - val_loss: 1197.7612
# Epoch 2/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 858.9404 - val_loss: 982.3484
# Epoch 3/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 706.7048 - val_loss: 897.7258
# Epoch 4/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 647.0964 - val_loss: 849.8855
# Epoch 5/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 608.6923 - val_loss: 799.7708
# Epoch 6/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 569.0334 - val_loss: 754.0721
# Epoch 7/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 532.8422 - val_loss: 715.9870
# Epoch 8/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 502.6246 - val_loss: 683.1998
# Epoch 9/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 476.7841 - val_loss: 654.6616
# Epoch 10/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 453.7303 - val_loss: 628.4897
# Epoch 11/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 432.9923 - val_loss: 604.5473
# Epoch 12/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 414.1923 - val_loss: 582.5958
# Epoch 13/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 396.8443 - val_loss: 562.4875
# Epoch 14/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 381.1823 - val_loss: 543.8046
# Epoch 15/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 366.7188 - val_loss: 526.6176
# Epoch 16/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 353.5190 - val_loss: 510.6371
# Epoch 17/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 341.2527 - val_loss: 496.6283
# Epoch 18/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 333.5066 - val_loss: 481.8239
# Epoch 19/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 319.3618 - val_loss: 469.0131
# Epoch 20/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 309.6418 - val_loss: 456.8076
# Epoch 21/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 300.5115 - val_loss: 443.0645
# Epoch 22/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 290.3239 - val_loss: 431.4735
# Epoch 23/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 281.2861 - val_loss: 417.7392
# Epoch 24/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 271.8563 - val_loss: 406.9532
# Epoch 25/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 264.3173 - val_loss: 397.1729
# Epoch 26/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 257.5303 - val_loss: 388.0118
# Epoch 27/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 251.0231 - val_loss: 379.4690
# Epoch 28/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 245.0793 - val_loss: 371.2177
# Epoch 29/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 239.3667 - val_loss: 361.7345
# Epoch 30/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 233.4443 - val_loss: 353.1754
# Epoch 31/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 227.5416 - val_loss: 346.0163
# Epoch 32/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 222.7359 - val_loss: 338.8827
# Epoch 33/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 218.3639 - val_loss: 332.3185
# Epoch 34/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 214.0174 - val_loss: 325.9366
# Epoch 35/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 209.9877 - val_loss: 319.8559
# Epoch 36/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 206.1621 - val_loss: 313.8846
# Epoch 37/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 202.5643 - val_loss: 308.1705
# Epoch 38/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 199.1030 - val_loss: 302.6189
# Epoch 39/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 195.8335 - val_loss: 297.2907
# Epoch 40/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 192.7242 - val_loss: 292.1466
# Epoch 41/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 189.7720 - val_loss: 287.2050
# Epoch 42/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 186.9736 - val_loss: 282.4461
# Epoch 43/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 184.2621 - val_loss: 277.8367
# Epoch 44/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 181.7086 - val_loss: 273.3974
# Epoch 45/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 179.1958 - val_loss: 269.0104
# Epoch 46/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 176.9008 - val_loss: 264.8286
# Epoch 47/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 174.6265 - val_loss: 260.8066
# Epoch 48/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 172.6389 - val_loss: 256.8981
# Epoch 49/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 170.4927 - val_loss: 253.1496
# Epoch 50/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 168.5795 - val_loss: 249.4677
# Epoch 51/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 166.6306 - val_loss: 245.9511
# Epoch 52/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 164.8556 - val_loss: 242.4623
# Epoch 53/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 163.0367 - val_loss: 239.1304
# Epoch 54/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 161.4193 - val_loss: 235.8564
# Epoch 55/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 159.7103 - val_loss: 232.7347
# Epoch 56/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 158.2151 - val_loss: 229.6591
# Epoch 57/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 156.6208 - val_loss: 226.6650
# Epoch 58/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 155.1966 - val_loss: 223.8119
# Epoch 59/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 153.7124 - val_loss: 221.0226
# Epoch 60/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 152.5022 - val_loss: 218.3259
# Epoch 61/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 151.1302 - val_loss: 215.5559
# Epoch 62/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 149.8366 - val_loss: 213.1177
# Epoch 63/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 148.6106 - val_loss: 210.4995
# Epoch 64/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 147.5059 - val_loss: 208.1765
# Epoch 65/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 146.3115 - val_loss: 205.7023
# Epoch 66/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 145.2822 - val_loss: 203.5350
# Epoch 67/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 144.1949 - val_loss: 201.1830
# Epoch 68/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 143.2710 - val_loss: 199.1575
# Epoch 69/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 142.2262 - val_loss: 196.9421
# Epoch 70/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 141.3808 - val_loss: 195.0325
# Epoch 71/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 140.3957 - val_loss: 192.9713
# Epoch 72/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 139.5991 - val_loss: 191.1516
# Epoch 73/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 138.7091 - val_loss: 189.2518
# Epoch 74/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 137.9607 - val_loss: 187.4889
# Epoch 75/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 137.1807 - val_loss: 185.7216
# Epoch 76/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 136.4715 - val_loss: 184.0441
# Epoch 77/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 135.7714 - val_loss: 182.3949
# Epoch 78/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 135.1068 - val_loss: 180.8063
# Epoch 79/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 134.4689 - val_loss: 179.2670
# Epoch 80/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 133.8505 - val_loss: 177.7624
# Epoch 81/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 133.2639 - val_loss: 176.3235
# Epoch 82/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 132.6905 - val_loss: 174.9000
# Epoch 83/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 132.1453 - val_loss: 173.5409
# Epoch 84/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 131.6152 - val_loss: 172.2014
# Epoch 85/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 131.1062 - val_loss: 170.9204
# Epoch 86/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 130.6099 - val_loss: 169.6657
# Epoch 87/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 130.1361 - val_loss: 168.4840
# Epoch 88/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 129.7152 - val_loss: 167.3284
# Epoch 89/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 129.2411 - val_loss: 166.1571
# Epoch 90/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 128.7981 - val_loss: 165.0574
# Epoch 91/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 128.3912 - val_loss: 164.0021
# Epoch 92/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 127.9966 - val_loss: 162.9810
# Epoch 93/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 127.6171 - val_loss: 161.9944
# Epoch 94/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 127.2434 - val_loss: 161.0468
# Epoch 95/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 126.8767 - val_loss: 160.1303
# Epoch 96/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 126.5164 - val_loss: 159.2437
# Epoch 97/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 126.1656 - val_loss: 158.3799
# Epoch 98/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 125.8180 - val_loss: 157.5427
# Epoch 99/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 125.4716 - val_loss: 156.7132
# Epoch 100/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 125.1244 - val_loss: 155.8878
# Epoch 101/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 124.7818 - val_loss: 155.0693
# Epoch 102/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 124.4400 - val_loss: 154.2666
# Epoch 103/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 124.0951 - val_loss: 153.4708
# Epoch 104/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 123.7504 - val_loss: 152.6946
# Epoch 105/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 123.4082 - val_loss: 151.9329
# Epoch 106/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 123.0674 - val_loss: 151.1899
# Epoch 107/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 122.7263 - val_loss: 150.4560
# Epoch 108/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 122.3850 - val_loss: 149.7281
# Epoch 109/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 122.0475 - val_loss: 149.0063
# Epoch 110/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 121.7120 - val_loss: 148.3050
# Epoch 111/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 121.3760 - val_loss: 147.6107
# Epoch 112/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 121.0390 - val_loss: 146.9547
# Epoch 113/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 120.7014 - val_loss: 146.3142
# Epoch 114/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 120.3577 - val_loss: 145.7110
# Epoch 115/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 120.0191 - val_loss: 145.1077
# Epoch 116/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 119.6912 - val_loss: 144.5094
# Epoch 117/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 119.3775 - val_loss: 143.9119
# Epoch 118/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 119.0698 - val_loss: 143.3316
# Epoch 119/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 118.7669 - val_loss: 142.7778
# Epoch 120/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 118.4609 - val_loss: 142.2469
# Epoch 121/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 118.1565 - val_loss: 141.6957
# Epoch 122/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 117.8567 - val_loss: 141.1675
# Epoch 123/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 117.5682 - val_loss: 140.6697
# Epoch 124/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 117.3080 - val_loss: 140.1625
# Epoch 125/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 117.0022 - val_loss: 139.7385
# Epoch 126/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 116.7484 - val_loss: 139.1893
# Epoch 127/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 116.4942 - val_loss: 138.7722
# Epoch 128/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 116.3125 - val_loss: 138.3006
# Epoch 129/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 116.0846 - val_loss: 137.6053
# Epoch 130/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 115.8726 - val_loss: 137.3961
# Epoch 131/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 115.6626 - val_loss: 136.8459
# Epoch 132/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 115.3063 - val_loss: 136.4264
# Epoch 133/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 115.3432 - val_loss: 135.9685
# Epoch 134/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 114.9202 - val_loss: 135.3212
# Epoch 135/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 114.7307 - val_loss: 135.2604
# Epoch 136/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 114.4087 - val_loss: 134.7699
# Epoch 137/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 114.1395 - val_loss: 134.5629
# Epoch 138/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 113.8898 - val_loss: 133.9883
# Epoch 139/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 113.6663 - val_loss: 133.7726
# Epoch 140/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 113.4402 - val_loss: 133.1879
# Epoch 141/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 113.2388 - val_loss: 132.9686
# Epoch 142/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 113.0158 - val_loss: 132.4150
# Epoch 143/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 112.8195 - val_loss: 132.2494
# Epoch 144/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 112.5680 - val_loss: 131.6624
# Epoch 145/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 112.4104 - val_loss: 131.5708
# Epoch 146/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 112.1422 - val_loss: 131.0174
# Epoch 147/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 112.0068 - val_loss: 130.9620
# Epoch 148/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 111.7603 - val_loss: 130.5047
# Epoch 149/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 111.5264 - val_loss: 130.2185
# Epoch 150/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 111.4801 - val_loss: 129.7868
# Epoch 151/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 111.2468 - val_loss: 129.5477
# Epoch 152/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 110.8620 - val_loss: 129.3935
# Epoch 153/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 110.6131 - val_loss: 128.8703
# Epoch 154/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 110.3475 - val_loss: 128.5560
# Epoch 155/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 110.1649 - val_loss: 128.2969
# Epoch 156/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 109.9068 - val_loss: 127.9370
# Epoch 157/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.7045 - val_loss: 127.6816
# Epoch 158/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 109.4781 - val_loss: 127.3307
# Epoch 159/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.2570 - val_loss: 127.4858
# Epoch 160/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.0424 - val_loss: 127.1903
# Epoch 161/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 108.7080 - val_loss: 126.9058
# Epoch 162/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 108.4633 - val_loss: 126.4349
# Epoch 163/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 108.2824 - val_loss: 126.1981
# Epoch 164/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 108.0979 - val_loss: 126.0180
# Epoch 165/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 107.9277 - val_loss: 125.7642
# Epoch 166/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 107.7799 - val_loss: 125.2491
# Epoch 167/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 107.5854 - val_loss: 124.9273
# Epoch 168/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 107.3846 - val_loss: 124.6075
# Epoch 169/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 107.0582 - val_loss: 124.6017
# Epoch 170/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 106.8609 - val_loss: 124.5313
# Epoch 171/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 106.8447 - val_loss: 124.1601
# Epoch 172/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 106.5856 - val_loss: 124.4062
# Epoch 173/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 106.5195 - val_loss: 125.1725
# Epoch 174/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 106.6645 - val_loss: 124.5661
# Epoch 175/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 106.6692 - val_loss: 124.3043
# Epoch 176/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 106.1823 - val_loss: 124.0054
# Epoch 177/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 105.9914 - val_loss: 124.2095
# Epoch 178/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 105.7535 - val_loss: 123.6698
# Epoch 179/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 105.9885 - val_loss: 125.0831
# Epoch 180/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 105.5030 - val_loss: 123.4720
# Epoch 181/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 104.9424 - val_loss: 123.0796
# Epoch 182/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 104.5829 - val_loss: 122.8113
# Epoch 183/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 104.3339 - val_loss: 122.5187
# Epoch 184/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 104.0422 - val_loss: 122.5593
# Epoch 185/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 103.7495 - val_loss: 122.4000
# Epoch 186/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 103.5099 - val_loss: 122.5914
# Epoch 187/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 103.2354 - val_loss: 122.3209
# Epoch 188/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 103.0080 - val_loss: 122.3931
# Epoch 189/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 103.0293 - val_loss: 122.1790
# Epoch 190/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 102.8316 - val_loss: 121.8314
# Epoch 191/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 102.3725 - val_loss: 122.0054
# Epoch 192/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 102.0897 - val_loss: 121.8992
# Epoch 193/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 101.9509 - val_loss: 122.2137
# Epoch 194/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 101.6818 - val_loss: 121.4127
# Epoch 195/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 101.4829 - val_loss: 121.9421
# Epoch 196/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 101.3279 - val_loss: 121.2684
# Epoch 197/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 101.0858 - val_loss: 121.5626
# Epoch 198/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 100.8182 - val_loss: 121.1094
# Epoch 199/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 100.7358 - val_loss: 121.2164
# Epoch 200/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 100.4057 - val_loss: 120.4793

# %%
# display loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
X_test.shape ,y_test.shape
# Out:
# ((700, 30, 1), (700, 30, 1))

# %%
# make a full prediction on the test data, then plot the result on dataframe

# %%
# make a prediction and evaluuate
y_pred = model.predict(X_test[-1].reshape(1, next_t, 1))
# reshape the data
y_pred = y_pred.reshape(-1, 1)
print(y_pred.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# (30, 1)

# %%
# Last date of the test data
last_date = test['Date'].values[-1]

# Create the next 30 days date range
next_t = 30
next_t_days = pd.date_range(last_date, periods=next_t)

# Concatenate the last 30 days and the next 30 days into a new dataframe named big_df based on random_df_copy
big_df = random_df_copy.copy()
predicted_values_df = pd.DataFrame({'Date': next_t_days, '36T': None})
big_df = pd.concat([big_df, predicted_values_df], ignore_index=True)

big_df.tail()
# Out:
# /tmp/ipykernel_13823/3019929442.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   big_df = pd.concat([big_df, predicted_values_df], ignore_index=True)
#            Date  36T
# 4772 2024-01-25  NaN
# 4773 2024-01-26  NaN
# 4774 2024-01-27  NaN
# 4775 2024-01-28  NaN
# 4776 2024-01-29  NaN

# %%
import datetime
# Calculate the date 2 years ago from the current date
two_years_ago = datetime.datetime.now() - datetime.timedelta(days=365*2)

# Filter the dataframe based on the date range
filtered_df = big_df[big_df['Date'] >= two_years_ago]

# Plot the filtered dataframe
plt.figure(figsize=(10,5))
plt.plot(filtered_df['Date'], filtered_df['36T'], label='Actual')
# plot on predicted values
plt.plot(next_t_days, y_pred, label='Predictions')
plt.legend()
plt.show()
